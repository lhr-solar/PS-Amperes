# %% [markdown]
# $V_{ovr} = \frac{R_{bot} * V_{ov}}{R_{top} + R_{bot}} $

# %%
#Over Voltage Rising Threshold Calulations
Rbot = 7.32e3 #in Ohms
Rtop = 100e3 #in Ohms

Rtol = 0.01 #Tolerance of Resistors

Vovr_min = 1.165
Vovr_typ = 1.25
Vovr_max = 1.333

Vov_min = Vovr_min * ((Rbot*(1 + Rtol) + Rtop*(1 - Rtol)) / (Rbot*(1 + Rtol)))
Vov_typ = Vovr_typ * (Rbot + Rtop) / (Rbot)
Vov_max = Vovr_max * ((Rbot*(1 - Rtol) + Rtop*(1 + Rtol)) / (Rbot*(1 - Rtol)))
                      
print(f"Vov_min = {Vov_min}")
print(f"Vov_typ = {Vov_typ}")
print(f"Vov_max = {Vov_max}")
# Out:
# Vov_min = 16.76514608018179
# Vov_typ = 18.32650273224044
# Vov_max = 19.9112690290887

# %%
#Over Voltage Falling Threshold Calculations
Rbot = 7.32e3 #in Ohms
Rtop = 100e3 #in Ohms

Rtol = 0.01 #Tolerance of Resistors

Vovr_min = 1.063
Vovr_typ = 1.143
Vovr_max = 1.222

Vov_min = Vovr_min * ((Rbot*(1 + Rtol) + Rtop*(1 - Rtol)) / (Rbot*(1 + Rtol)))
Vov_typ = Vovr_typ * (Rbot + Rtop) / (Rbot)
Vov_max = Vovr_max * ((Rbot*(1 - Rtol) + Rtop*(1 + Rtol)) / (Rbot*(1 - Rtol)))
                      
print(f"Vov_min = {Vov_min}")
print(f"Vov_typ = {Vov_typ}")
print(f"Vov_max = {Vov_max}")
# Out:
# Vov_min = 15.297296380457716
# Vov_typ = 16.757754098360657
# Vov_max = 18.25324137550367

# %% [markdown]
# $ V_{un} = V_{uv}(1+ \frac{R_{bot}}{R_{top}}) $

# %%
#Under Voltage Rising Threshold Calculations
Rbot = 15.8e3 #in Ohms
Rtop = 100e3 #in Ohms

Rtol = 0.01 #Tolerance of Resistors


Vuv_min = 1.16
Vuv_typ = 1.24
Vuv_max = 1.32

Vun_min = Vuv_min * (1 + (Rtop * (1 - Rtol)) / (Rbot * (1 + Rtol)))
Vun_typ = Vuv_typ * (1 + (Rtop/Rbot))
Vun_max = Vuv_max * (1 + (Rtop * (1 + Rtol) / (Rbot * (1 - Rtol))))

print(f" Vun_min = {Vun_min}")
print(f" Vun_typ = {Vun_typ}")
print(f" Vun_max = {Vun_max}")
# Out:
#  Vun_min = 8.356390525128461
#  Vun_typ = 9.088101265822784
#  Vun_max = 9.843206751054852

# %%
#Under Voltage Falling Threshold Calculations
Rbot = 100e3 #in Ohms
Rtop = 15.8e3 #in Ohms

Rtol = 0.01 #Tolerance of Resistors


Vuv_min = 1.027
Vuv_typ = 1.14
Vuv_max = 1.235

Vun_min = Vuv_min * (1 + (Rbot * (1 - Rtol)) / (Rtop * (1 + Rtol)))
Vun_typ = Vuv_typ * (1 + (Rbot/Rtop))
Vun_max = Vuv_max * (1 + (Rbot * (1 + Rtol) / (Rtop * (1 - Rtol))))

print(f" Vun_min = {Vun_min}")
print(f" Vun_typ = {Vun_typ}")
print(f" Vun_max = {Vun_max}")
# Out:
#  Vun_min = 7.39828712871287
#  Vun_typ = 8.355189873417721
#  Vun_max = 9.209363892085412
